# %% [markdown]
# <a href="https://colab.research.google.com/github/ayarzuki/Orbit-Futur-Academy/blob/main/Introduction_Fundamental_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction Fundamental Python
# ![google](https://miro.medium.com/max/986/1*pimj8lXWwZnqLs2xVCV2Aw.png)
# ![google](https://www.google.co.th/images/branding/googlelogo/1x/googlelogo_color_272x92dp.png)
# ![python](https://www.python.org/static/img/psf-logo.png)

# %% [markdown]
# ![WhatsApp Image 2021-09-18 at 00.59.27.jpeg](data:image/jpeg;base64,...)
#
# ### Note: Penggunaan Markdown pada Jupyter Notebook Atau Google Colab

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Belajar Python
# ## Intro Python
# ### List Pembahasan Python Basic

# %% [markdown]
# ***
# ---

# %% [markdown]
# Basic Type Object
# 1. Numbers
# 2. Strings
# 3. Boolean
# 4. List

# %% [markdown]
# ### 2. Basic Python - Aturan Penulisan Statement pada Python

# %%
# 1. Penulisan satu statement di dalam Python tidak diakhiri dengan tanda titik-koma
print("Halo Dunia!")
print("panjang = 100")
print("lebar = 23")
# Out:
# Halo Dunia!
# panjang = 100
# lebar = 23

# %%
# 2. Statement pada Pyhton dinyatakan dalam satu baris. Jadi akhir dari sebuah pernyataan adalah baris baru (new line).
print("luas = panjang * lebar")
# Out:
# luas = panjang * lebar

# %%
# 3. Jika ada pernyataan yang panjangnya terdiri lebih dari 1 baris, maka dapat dilakukan dengan menggunakan tanda backslash (\).
print("volume = panjang * lebar *\
 tinggi")
# Out:
# volume = panjang * lebar * tinggi

# %%
# 4. Statement yang ada di dalam atau diapit oleh tanda kurung seperti "[],{},()" tidak memerlukan tanda "".
nama_hari = ['Senin','Selasa','Rabu','Kamis','Jumat','Sabtu']
print(nama_hari)
# Out:
# ['Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu']

# %%
# 5. Python menggunakan tanda indentasi (spasi) sebagai penanda blok. Panjang spasi atau indentasi untuk setiap baris yang ada dalam satu blok kode harus sama. Bila spasi atau indentasi dalam satu grup kode tersebut tidak sama, python akan menamplikan sintaks error.
usia = 6
if usia >= 4:
    print("diterima masuk SD")
    print("dinyatakan lulus")
else:
    print("tidak diterima masuk SD")
    print("dinyatakan gagal")
# Out:
# diterima masuk SD
# dinyatakan lulus

# %%
# 6. Sebaga penanda string, Python menggunakan tanda kutip, baik tunggal ('), maupun ganda("). Tanda kutip tiga(""") digunakan untuk string multibaris.
namadepan = 'Alvin'
namalengkap = "Alvin Agusta Wahyono"
alinea = """Berikut ini adalah alinea
yang terdiri dari beberapa baris."""
print(namadepan)
print(namalengkap)
print(alinea)
# Out:
# Alvin
# Alvin Agusta Wahyono
# Berikut ini adalah alinea
# yang terdiri dari beberapa baris.

# %%
# 7. Bahasa Python bersifat case sensitif, yang berarti membedakan huruf besar dan huruf kecil (memiliki nilai yang berbeda).
# Contoh statement yang benar
luas = "15*3"
#print(luas)
# Contoh statement yang salah
print(luas)
# Out:
# 15*3

# %% [markdown]
# ### 3. Python as Calculator (Numbers), Assignment, Comparison, Boolean, and Logic Operator

# %%
# 8. Untuk komentar di awali dengan tanda "#" yang artinya tidak diproses sebagai statement code.
panjang = 15
lebar = 3
luas = (panjang*lebar)
print(luas)
# Out:
# 45

# %%
# Contoh sederhana Boolean
nilai1 = 80
nilai2 = 65

output_boolean = nilai1 < nilai2
# output_boolean = nilai1 > nilai2

print(output_boolean)
# Out:
# False

# %%
list = [100, 10000, 2.2, 3.14, 'belajar', 'python']

print(list)
# Out:
# [100, 10000, 2.2, 3.14, 'belajar', 'python']

# %% [markdown]
# #### a. Python Working in Strings and List

# %%
#String pendek
print('pendek')
print("pendek")
print("don't")

#Tanda \ (Menghilangkan pengaruh "")
# print(""Siap!" kata orang itu")
print("\"Siap!\" kata orang itu")

#String lebih dari satu baris
print('''
string
panjang
tiga baris
''')
# Out:
# pendek
# pendek
# don't
# "Siap!" kata orang itu
#
# string
# panjang
# tiga baris

# %%
#Operator Penjumlahan String
print("Py" + "thon")
prefiks = "di"
dasar_1 = "terima"
dasar_2 = "tolak"
print(prefiks + dasar_1)
print(prefiks, dasar_2)
print("Py" "thon")
# Out:
# Python
# diterima
# di tolak
# Python

# %%
#Tanda \ dan r
#Tanda \ berguna sebagai penginterpretasi karakter spesial sedangkan r membuat string menjadi terbaca sebagai raw strings (apa adanya)
print("ganti baris \nke bawah")  # \n turun satu baris


#print("C:\user\folder") # error
print(r"C:\user\folder") # berhasil
# Out:
# ganti baris
# ke bawah
# C:\user\folder

# %%
#Setiap data di dalam String dapat diakses dengan indeks yang dimulai dari 0.
#Indexed


kata_sambutan = "Hello"

#kata_sambutan[0] #	indeks ke-0
#kata_sambutan[:2] #	indeks ke-0 sampai indeks ke-1
#kata_sambutan[1:2] #	indeks ke 1 saja
#kata_sambutan[1:] #	indeks ke-1 sampai terakhir
#kata_sambutan[-2] #	indeks ke-1 dari belakang
kata_sambutan[0] #	indeks ke-0
#kata_sambutan[:-3] #	dari indeks ke-0 sampai setelah indeks ke-3 dari terakhir
# Out:
# 'H'

# %%
#Metode Upper dan Lower

#kata_sambutan.lower() #mengubah String menjadi huruf kecil
kata_sambutan.upper() #mengubah String menjadi huruf kapital
# Out:
# 'HELLO'

# %%
print(kata_sambutan)
# Out:
# Hello

# %%
#Fungsi len dan operator in
sambutan = kata_sambutan + ", Pak Febri. Ada yang bisa Elen bantu?"

len(sambutan) #panjang karakter len

# Untuk mengetahui sebuah nilai atau objek ada dalam list, kita dapat menggunakan operator in dan not in. Fungsi ini akan mengembalikan nilai boolean True atau False.
#print("Elen" in sambutan)
#print("Febri" in sambutan)
# Out:
# 43

# %%
print(sambutan)
# Out:
# Hello, Pak Febri. Ada yang bisa Elen bantu?

# %% [markdown]
# #### b. List

# %%
#Create list
akurasi = [0.6,0.7, 0.8, 0.9]
kredit = ['macet', 'lancar', 'macet']
feature = [1,2,3,4]
container_1 = akurasi
#container_2 = kredit
type(container_1) # mengecek tipe
# Out:
# list

# %%
#Concatenating (operator +)
concat = akurasi+feature
#print(concat)

cacah = [1, 3, 5, 7, 9] + [2, 4, 6, 8]
#print(cacah)

dua_list = [akurasi, feature]
print(dua_list)

campur = feature + kredit
# print(campur)
# Out:
# [[0.6, 0.7, 0.8, 0.9], [1, 2, 3, 4]]

# %%
#Indexed
feature = [1,2,3,4]
#feature[0]
#feature[:3] #indeks ke-0 sampai ke-2
feature[1:] #indeks ke-1 sampai terakhir
# Out:
# [2, 3, 4]

# %%
print(cacah)
# Out:
# [1, 3, 5, 7, 9, 2, 4, 6, 8]

# %%
#indexed-2
#cacah[1] = 3
cacah[1:4] = [9,9,9]

# %%
print(cacah)
# Out:
# [1, 9, 9, 9, 9, 2, 4, 6, 8]

# %%
lakes = ['superior', 'erie', 'huron', 'ontario', 'powell']
len(lakes) #jumlah index yang ada di dalam list
# Out:
# 5

# %%
numbers = [1, 2, 3, 4, 5]
#sum(numbers) #penjumlahan semua indeks atau elemen yang ada dalam list
#max(numbers) # nilai terbesar di dalam List
min(numbers) # nilai terkecil di dalam List
# Out:
# 1

# %%
lakes_sorted_new = sorted(lakes) # mengurutkan sesuai abjad di dalam List
lakes_sorted_new
# Out:
# ['erie', 'huron', 'ontario', 'powell', 'superior']

# %%
cities = ["oslo", "delhi", "washington", "london", "seattle", "paris", "washington", "seattle"]
#cities.count('seattle') # menghitung jumlah elemen yang sama di dalam List
cities.index('washington') #indeks ke berapa(?)
# Out:
# 2

# %%
cities.reverse()
cities
# Out:
# ['seattle',
#  'washington',
#  'paris',
#  'seattle',
#  'london',
#  'washington',
#  'delhi',
#  'oslo']

# %%
cities.append('brussels') # menambah elemen pada List
cities
# Out:
# ['seattle',
#  'washington',
#  'paris',
#  'seattle',
#  'london',
#  'washington',
#  'delhi',
#  'oslo',
#  'brussels']

# %%
cities.sort() # mengurutkan sesuai abjad di dalam List
cities
# Out:
# ['brussels',
#  'delhi',
#  'london',
#  'oslo',
#  'paris',
#  'seattle',
#  'seattle',
#  'washington',
#  'washington']

# %%
print(cities)
# Out:
# ['london', 'oslo', 'paris', 'seattle', 'seattle', 'washington', 'brussels', 'copenhagen']

# %%
cities.pop(1) # menghapus elemen dalam List
cities
# Out:
# ['london',
#  'paris',
#  'seattle',
#  'seattle',
#  'washington',
#  'brussels',
#  'copenhagen']

# %%
more_cities = ["brussels", "copenhagen"] 
cities.extend(more_cities) # menambah elemen di dalam list
cities
# Out:
# ['brussels',
#  'london',
#  'oslo',
#  'paris',
#  'seattle',
#  'seattle',
#  'washington',
#  'brussels',
#  'copenhagen']

# %%
cities.remove("brussels") #menghapus elemen di dalam List
cities
# Out:
# ['london',
#  'oslo',
#  'paris',
#  'seattle',
#  'seattle',
#  'washington',
#  'brussels',
#  'copenhagen']

# %% [markdown]
# ### Thank You

# %%
kata_sambutan= "Hello"
kata_sambutan[:0] # indeks ke 0
#kata_sambutan[:2]# indeks ke 0 sampai 2-1
#kata_sambutan[1:2]# indeks ke 1 sampai 2-1
# Out:
# ''
